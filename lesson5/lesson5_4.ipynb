# %% [markdown]
# ## Python 內建函數呼叫
# ```
# import 函數名
# ```

# %%
import random
import time

for i in range(100):
    print(random.randint(1, 10))
    time.sleep(0.1)

# %% [markdown]
# ## 外部的module
# 1. 找到說明書
# 2. 如何使用requests
#
# * function class 常數
# * Response的實體:
#
#  * attribute(屬性)可儲存資料
#  * property(屬性)可儲存資料
#  * method方法

# %%
import requests

r = requests.get('https://api.github.com/events')

print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
r.text
# Out:
# '[{"id":"41926742358","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":799423558,"name":"setiaone961/lava-commit","url":"https://api.github.com/repos/setiaone961/lava-commit"},"payload":{"repository_id":799423558,"push_id":20235281302,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"cac7dfd81005cd7e49277052ed6fbcec8a91dae9","before":"ce8ba92925f595cc3f5103c34fc93530c69078e9","commits":[{"sha":"cac7dfd81005cd7e49277052ed6fbcec8a91dae9","author":{"email":"ujangsetiawan996@gmail.com","name":"setiaone961"},"message":"✨ Feature Ethereum network","distinct":true,"url":"https://api.github.com/repos/setiaone961/lava-commit/commits/cac7dfd81005cd7e49277052ed6fbcec8a91dae9"}]},"public":true,"created_at":"2024-09-14T07:40:59Z"},{"id":"41926742350","type":"PushEvent","actor":{"i
# ...
