# %%
import sqlite3
from sqlite3 import Error


try:
    conn = sqlite3.connect('./data/pico.db')
except Exception as e:
    print(e)

# %%
sql = """
    INSERT INTO 雞舍 (時間,設備,值)
    VALUES(?,?,?)
    """
cursor = conn.cursor()
cursor.execute(sql,('2024-10-26 01:15:37','SA-56/TEMPERATURE',30.32))
conn.commit()
cursor.close()
conn.close()
